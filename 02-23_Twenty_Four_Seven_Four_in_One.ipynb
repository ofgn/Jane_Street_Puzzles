# %% [markdown]
# https://www.janestreet.com/puzzles/current-puzzle/
#
# Status: Solved
#
# Hint: Look into solving Suduko with linear programming
#
# My solution will be uploaded after submissions for the leaderboard are closed.
